# %%
import pandas as pd
import numpy as np
df = pd.read_csv("social_media_viral_content_dataset.csv")

# %% [markdown]
# Task 1: Load the Dataset

# %%
df.head(10)
# Out:
#      post_id        platform content_type       topic language    region  \
# 0  SM_100000       Instagram         text      Sports       ur        UK
# 1  SM_100001       Instagram     carousel      Sports       ur    Brazil
# 2  SM_100002  YouTube Shorts        video  Technology       ur        UK
# 3  SM_100003               X         text    Politics       ur        US
# 4  SM_100004  YouTube Shorts         text   Education       es        US
# 5  SM_100005       Instagram     carousel      Sports       hi    Brazil
# 6  SM_100006               X         text   Education       hi        UK
# 7  SM_100007               X         text  Technology       es  Pakistan
# 8  SM_100008  YouTube Shorts         text      Sports       es  Pakistan
# 9  SM_100009  YouTube Shorts        video    Politics       en        US
#
#          post_datetime                           hashtags    views   likes  \
# 0  2024-12-10 00:00:00                #tech #funny #music  2319102  122058
# ...

# %%
df.tail()
# Out:
#         post_id        platform content_type      topic language    region  \
# 1995  SM_101995  YouTube Shorts         text     Sports       es        US
# 1996  SM_101996       Instagram         text   Politics       en    Brazil
# 1997  SM_101997               X     carousel  Education       ur        UK
# 1998  SM_101998               X     carousel     Sports       ur        UK
# 1999  SM_101999               X     carousel   Politics       ur  Pakistan
#
#             post_datetime                hashtags     views   likes  comments  \
# 1995  2024-02-11 00:00:00       #funny #music #ai  14112183  486627      9430
# 1996  2024-02-12 00:00:00        #viral #trending   5604744  467062      2764
# 1997  2024-05-01 00:00:00          #trending #fyp   2031920  253990     40963
# 1998  2024-12-23 00:00:00  #funny #trending #tech   5237350  209494     15042
# 1999  2024-11-04 00:00:00           #viral #funny   3369429  481347     13455
#
# ...

# %%
df.shape
# Out:
# (2000, 15)

# %% [markdown]
# Task 2: Data Inspection

# %%
df.columns
# Out:
# Index(['post_id', 'platform', 'content_type', 'topic', 'language', 'region',
#        'post_datetime', 'hashtags', 'views', 'likes', 'comments', 'shares',
#        'engagement_rate', 'sentiment_score', 'is_viral'],
#       dtype='object')

# %%
df.dtypes
# Out:
# post_id             object
# platform            object
# content_type        object
# topic               object
# language            object
# region              object
# post_datetime       object
# hashtags            object
# views                int64
# likes                int64
# comments             int64
# shares               int64
# engagement_rate    float64
# sentiment_score    float64
# is_viral             int64
# dtype: object

# %%
df.isnull().any()
# Out:
# post_id            False
# platform           False
# content_type       False
# topic              False
# language           False
# region             False
# post_datetime      False
# hashtags           False
# views              False
# likes              False
# comments           False
# shares             False
# engagement_rate    False
# sentiment_score    False
# is_viral           False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# post_id            0
# platform           0
# content_type       0
# topic              0
# language           0
# region             0
# post_datetime      0
# hashtags           0
# views              0
# likes              0
# comments           0
# shares             0
# engagement_rate    0
# sentiment_score    0
# is_viral           0
# dtype: int64

# %% [markdown]
# Task 3: Numerical Analysis (NumPy + Pandas)

# %%
data =  df['likes'].to_numpy()
print(data)
# Out:
# [122058 110368  87598 ... 253990 209494 481347]

# %%
mean = np.mean(data)
print(mean)
# Out:
# 245329.244

# %%
median = np.median(data)
print(median)
# Out:
# 239831.0

# %%
min = np.median(data)
print(median)
# Out:
# 239831.0

# %%
max = np.mean(data)
print(max)
# Out:
# 245329.244

# %%
std = min = np.std(data)
print(std)
# Out:
# 144996.16094290724

# %% [markdown]
# Task 4: Basic Visualization (Matplotlib)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df['likes'].head(10))
plt.show()

# %% [markdown]
# Task 5: Insight

# %% [markdown]
# 1. The line chart shows that the number of likes **varies across observations**, indicating fluctuations in user engagement rather than a constant pattern.
#
# 2. There is a **noticeable difference between the highest and lowest values** in the likes data, suggesting that some posts receive significantly more engagement than others.
#
# 3. The distribution of likes indicates **inconsistency in performance**, which may be influenced by factors such as content quality, posting time, or audience reach.
